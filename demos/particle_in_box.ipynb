# %%
from chem455 import *
import matplotlib.pyplot as plt

# %%
n = 2
L = 5
x = np.linspace(-L/2,3/2*L,1001)
psi = box_wavefunction(n,x,L)

plt.subplot(2,1,1), plt.plot(x,psi)
plt.subplot(2,1,2), plt.plot(x,psi**2)
plt.xlabel('position')
# Out:
# Text(0.5, 0, 'position')

# %%
x = np.linspace(0,L,1001)
for n in range(0,4):
    psi = box_wavefunction(n,x,L)
    plt.plot(x,psi)
plt.xlabel('position')
# Out:
# Text(0.5, 0, 'position')
